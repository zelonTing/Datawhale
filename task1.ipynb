# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
env_path = '/home/ting/datasets/datawhale'
fpath = env_path + '/' + 'data1.csv'

# %%
data = pd.read_csv(fpath)

print('the number of data columns:',str(len(data.columns)))
# Out:
# the number of data columns: 90

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4754 entries, 0 to 4753
# Data columns (total 90 columns):
# id                                            4754 non-null int64
# custid                                        4754 non-null int64
# trade_no                                      4754 non-null float64
# bank_card_no                                  4754 non-null object
# low_volume_percent                            4752 non-null float64
# middle_volume_percent                         4752 non-null float64
# take_amount_in_later_12_month_highest         4754 non-null int64
# trans_amount_increase_rate_lately             4751 non-null float64
# trans_activity_month                          4752 non-null float64
# trans_activity_day                            4752 non-null float64
# transd_mcc                                    4752 non-null float64
# trans_days_interval_filter                    4746 non-null float64
# ...

# %%
data.head()
# Out:
#    id   custid      trade_no bank_card_no  low_volume_percent  \
# 0   5  2791858  2.018050e+31          卡号1                0.01
# 1  10   534047  2.018050e+31          卡号1                0.02
# 2  12  2849787  2.018050e+31          卡号1                0.04
# 3  13  1809708  2.018050e+31          卡号1                0.00
# 4  14  2499829  2.018050e+31          卡号1                0.01
#
#    middle_volume_percent  take_amount_in_later_12_month_highest  \
# 0                   0.99                                      0
# 1                   0.94                                   2000
# 2                   0.96                                      0
# 3                   0.96                                   2000
# 4                   0.99                                      0
#
#    trans_amount_increase_rate_lately  trans_activity_month  \
# 0                               0.90                  0.55
# 1                               1.28                  1.00
# ...

# %%
data.columns.values
# Out:
# array(['id', 'custid', 'trade_no', 'bank_card_no', 'low_volume_percent',
#        'middle_volume_percent', 'take_amount_in_later_12_month_highest',
#        'trans_amount_increase_rate_lately', 'trans_activity_month',
#        'trans_activity_day', 'transd_mcc', 'trans_days_interval_filter',
#        'trans_days_interval', 'regional_mobility', 'student_feature',
#        'repayment_capability', 'is_high_user',
#        'number_of_trans_from_2011', 'first_transaction_time',
#        'historical_trans_amount', 'historical_trans_day',
#        'rank_trad_1_month', 'trans_amount_3_month',
#        'avg_consume_less_12_valid_month', 'abs',
#        'top_trans_count_last_1_month', 'avg_price_last_12_month',
#        'avg_price_top_last_12_valid_month', 'reg_preference_for_trad',
#        'trans_top_time_last_1_month', 'trans_top_time_last_6_month',
#        'consume_top_time_last_1_month', 'consume_top_time_last_6_month',
#        'cross_consume_count_last_1_month',
# ...

# %%
data.describe()
# Out:
#                  id        custid      trade_no  low_volume_percent  \
# count   4754.000000  4.754000e+03  4.754000e+03         4752.000000
# mean    6008.414178  1.690993e+06  2.018050e+31            0.021806
# std     3452.071428  1.034235e+06  1.812890e+18            0.041527
# min        5.000000  1.140000e+02  2.018050e+31            0.000000
# 25%     3106.000000  7.593358e+05  2.018050e+31            0.010000
# 50%     6006.500000  1.634942e+06  2.018050e+31            0.010000
# 75%     8999.000000  2.597905e+06  2.018050e+31            0.020000
# max    11992.000000  4.004694e+06  2.018050e+31            1.000000
#
#        middle_volume_percent  take_amount_in_later_12_month_highest  \
# count            4752.000000                            4754.000000
# mean                0.901294                            1940.197728
# std                 0.144856                            3923.971494
# min                 0.000000                               0.000000
# ...

# %%
#删掉id_name,bank_card_no,trad_no,
data.drop(data.columns[[2,3]],axis=1, inplace=True)
data.drop('id_name',axis = 1, inplace=True)

# %%
data.info()

#
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4754 entries, 0 to 4753
# Data columns (total 87 columns):
# id                                            4754 non-null int64
# custid                                        4754 non-null int64
# low_volume_percent                            4752 non-null float64
# middle_volume_percent                         4752 non-null float64
# take_amount_in_later_12_month_highest         4754 non-null int64
# trans_amount_increase_rate_lately             4751 non-null float64
# trans_activity_month                          4752 non-null float64
# trans_activity_day                            4752 non-null float64
# transd_mcc                                    4752 non-null float64
# trans_days_interval_filter                    4746 non-null float64
# trans_days_interval                           4752 non-null float64
# regional_mobility                             4752 non-null float64
# ...

# %%
data.isnull().sum()
# Out:
# id                                          0
# custid                                      0
# low_volume_percent                          2
# middle_volume_percent                       2
# take_amount_in_later_12_month_highest       0
# trans_amount_increase_rate_lately           3
# trans_activity_month                        2
# trans_activity_day                          2
# transd_mcc                                  2
# trans_days_interval_filter                  8
# trans_days_interval                         2
# regional_mobility                           2
# student_feature                          2998
# repayment_capability                        0
# is_high_user                                0
# number_of_trans_from_2011                   2
# first_transaction_time                      2
# historical_trans_amount                     0
# historical_trans_day                        2
# rank_trad_1_month                           2
# ...

# %%
y = data['status']
x = data.drop(['student_feature','id'],axis = 1,inplace = True)

# %%
corr = data.corr()
sns.heatmap(corr,annot = True)
plt.show()

# %%
corr['status']
# Out:
# custid                                    0.051518
# low_volume_percent                        0.051846
# middle_volume_percent                     0.041132
# take_amount_in_later_12_month_highest    -0.001626
# trans_amount_increase_rate_lately        -0.009372
# trans_activity_month                      0.016952
# trans_activity_day                       -0.020671
# transd_mcc                               -0.000110
# trans_days_interval_filter               -0.006515
# trans_days_interval                       0.017021
# regional_mobility                        -0.035239
# repayment_capability                     -0.012323
# is_high_user                             -0.029112
# number_of_trans_from_2011                -0.044995
# first_transaction_time                    0.040626
# historical_trans_amount                  -0.033320
# historical_trans_day                     -0.038802
# rank_trad_1_month                         0.147258
# ...

# %%
cols = corr['status']

# %%
cols = cols[cols > 0]
cols
# Out:
# custid                                     0.051518
# low_volume_percent                         0.051846
# middle_volume_percent                      0.041132
# trans_activity_month                       0.016952
# trans_days_interval                        0.017021
# first_transaction_time                     0.040626
# rank_trad_1_month                          0.147258
# top_trans_count_last_1_month               0.117113
# avg_price_top_last_12_valid_month          0.071874
# trans_top_time_last_6_month                0.020683
# consume_top_time_last_6_month              0.023829
# trans_fail_top_count_enum_last_1_month     0.332256
# trans_fail_top_count_enum_last_6_month     0.133477
# trans_fail_top_count_enum_last_12_month    0.117161
# max_consume_count_later_6_month            0.017326
# railway_consume_count_last_12_month        0.025744
# status                                     1.000000
# trans_day_last_12_month                    0.078892
# ...

# %%
data[cols.index].head()
# Out:
#     custid  low_volume_percent  middle_volume_percent  trans_activity_month  \
# 0  2791858                0.01                   0.99                  0.55
# 1   534047                0.02                   0.94                  1.00
# 2  2849787                0.04                   0.96                  1.00
# 3  1809708                0.00                   0.96                  0.57
# 4  2499829                0.01                   0.99                  1.00
#
#    trans_days_interval  first_transaction_time  rank_trad_1_month  \
# 0                 26.0              20130817.0               0.40
# 1                 14.0              20160402.0               0.35
# 2                 22.0              20170617.0               1.00
# 3                  6.0              20130516.0               0.15
# 4                 42.0              20170312.0               0.65
#
#    top_trans_count_last_1_month  avg_price_top_last_12_valid_month  \
# ...

# %%
train_x = data[cols.index].copy()

# %%
for i in train_x.columns:
    train_x[i] = (train_x[i]- train_x[i].min())/(train_x[i].max()-train_x[i].min())

# %%
train_x.head()
# Out:
#      custid  low_volume_percent  middle_volume_percent  trans_activity_month  \
# 0  0.697138                0.01                   0.99              0.488636
# 1  0.133331                0.02                   0.94              1.000000
# 2  0.711603                0.04                   0.96              1.000000
# 3  0.451881                0.00                   0.96              0.511364
# 4  0.624214                0.01                   0.99              1.000000
#
#    trans_days_interval  first_transaction_time  rank_trad_1_month  \
# 0             0.095652                0.295888           0.368421
# 1             0.043478                0.718452           0.315789
# 2             0.078261                0.864354           1.000000
# 3             0.008696                0.291589           0.105263
# 4             0.165217                0.859997           0.631579
#
#    top_trans_count_last_1_month  avg_price_top_last_12_valid_month  \
# ...
